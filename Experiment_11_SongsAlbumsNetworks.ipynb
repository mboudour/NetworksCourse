# %% [markdown]
# <span style="font-size:large;">
# <div style="text-align: right">CSTS-UH 1078 <b>Networks</b><br/>
# Faculty: <b>Moses Boudourides</b><br/>
# Fall Semester 2019<br/>
# New York University Abu Dhabi</div>

# %% [markdown]
# ## <span style="color:red">EXPERIMENT 11</span>
# # <span style="color:green">Networks among Songs and Albums

# %%
import thecypher as cy
import pandas as pd
# import resource
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import pygraphviz
from networkx.drawing.nx_agraph import graphviz_layout
import warnings
warnings.filterwarnings('ignore')
# print resource.getrlimit(resource.RLIMIT_STACK)
# print sys.getrecursionlimit()
# max_rec = 0x100000
# # resource.setrlimit(resource.RLIMIT_STACK, [0x100 * max_rec, resource.RLIM_INFINITY])
# sys.setrecursionlimit(max_rec)

# %% [markdown]
# **Select a band having less than 30 albums!**

# %%
band='Led Zeppelin'
songs = cy.get_lyrics('Led Zeppelin')
print len(songs)
songs[0]
# Out:
# 2019-02-19 16:57:33,039 : INFO : GET Artist URL: http://lyrics.wikia.com/wiki/Led_Zeppelin
# 2019-02-19 16:57:34,245 : INFO : GET Artist Album: Houses of the Holy (1973)
# 2019-02-19 16:57:38,098 : INFO : GET Artist Album Successful: Houses of the Holy (1973)
# 2019-02-19 16:57:38,108 : INFO : GET Artist Album: BBC Sessions (1997)
# 2019-02-19 16:57:50,482 : INFO : GET Artist Album Successful: BBC Sessions (1997)
# 2019-02-19 16:57:50,492 : INFO : GET Artist Album: Led Zeppelin (1969)
# 2019-02-19 16:57:55,176 : INFO : GET Artist Album Successful: Led Zeppelin (1969)
# 2019-02-19 16:57:55,181 : INFO : GET Artist Album: Physical Graffiti (1975)
# 2019-02-19 16:58:03,163 : INFO : GET Artist Album Successful: Physical Graffiti (1975)
# 2019-02-19 16:58:03,166 : INFO : GET Artist Album: Coda (1982)
# 2019-02-19 16:58:08,536 : INFO : GET Artist Album Successful: Coda (1982)
# 2019-02-19 16:58:08,541 : INFO : GET Artist Album: Misc (0000)
# 2019-02-19 16:58:08,543 : INFO : GET Artist Album Successful: Misc (0000)
# 2019-02-19 16:58:08,545 : INFO : GET Artist Album: Led Zeppelin II (1969)
# 2019-02-19 16:58:20,616 : INFO : GET Artist Album Successful: Led Zeppelin II (1969)
# 2019-02-19 16:58:20,622 : INFO : GET Artist Album: How The West Was Won (2003)
# 2019-02-19 16:58:27,988 : INFO : GET Artist Album Successful: How The West Was Won (2003)
# 2019-02-19 16:58:28,007 : INFO : GET Artist Album: Edit
# 2019-02-19 16:58:30,775 : INFO : GET Artist Album Successful: Edit
# 2019-02-19 16:58:30,777 : INFO : GET Artist Album: Led Zeppelin IV (1971)
# 2019-02-19 16:58:33,820 : INFO : GET Artist Album Successful: Led Zeppelin IV (1971)
# 2019-02-19 16:58:33,835 : INFO : GET Artist Album: Presence (1976)
# 2019-02-19 16:58:36,736 : INFO : GET Artist Album Successful: Presence (1976)
# 2019-02-19 16:58:36,738 : INFO : GET Artist Album: The Song Remains the Same (1976)
# 2019-02-19 16:58:39,352 : INFO : GET Artist Album Successful: The Song Remains the Same (1976)
# 2019-02-19 16:58:39,353 : INFO : GET Artist Album: Led Zeppelin III (1970)
# 2019-02-19 16:58:41,518 : INFO : GET Artist Album Successful: Led Zeppelin III (1970)
# 2019-02-19 16:58:41,519 : INFO : GET Artist Album: In Through the Out Door (1979)
# 2019-02-19 16:58:43,748 : INFO : GET Artist Album Successful: In Through the Out Door (1979)
# 4577
# {'album': u'Houses of the Holy (1973)',
#  'album_genre': '',
#  'artist': 'Led Zeppelin',
#  'genre': '',
#  'id': 0L,
#  'lyric': u'It is the springtime of my loving',
#  'song': u'The Rain Song',
#  'year': u'1973'}

# %%
sdf = pd.DataFrame(songs)
group = ['song', 'year', 'album', 'genre', 'artist']
ldf = sdf.sort_values(group)\
       .groupby(group).lyric\
       .apply(' '.join)\
       .reset_index(name='lyric')
print len(ldf) 
ldf.rename(columns={'album': 'albumy'}, inplace=True)
ldf.columns
alb=[]
for i in range(len(ldf)):
    alb.append(ldf.iloc[i]['albumy'][:-7])
ldf['album']=alb
# ldf=ldf.drop('albumy', axis=1)
ldf=ldf.drop('genre', axis=1)
ldf=ldf.drop('artist', axis=1)
ldf=ldf[["song","album","year","albumy","lyric"]]
ldf
# Out:
# 123
#                                                   song  \
# 0                                  Achilles Last Stand
# 1                                          All My Love
# 2                             Babe I'm Gonna Leave You
# 3                                    Baby Come On Home
# 4                                  Black Country Woman
# 5                                            Black Dog
# 6                                            Black Dog
# 7                                            Black Dog
# 8                                      Boogie With Stu
# 9                                     Bring It On Home
# 10                                    Bring It On Home
# 11                                    Bron-Y-Aur Stomp
# 12                                    Bron-Y-Aur Stomp
# 13                                    Candy Store Rock
# 14                                       Carouselambra
# 15                                     Celebration Day
# 16                                     Celebration Day
# 17                             Communication Breakdown
# 18                             Communication Breakdown
# 19                                         Custard Pie
# 20                                        D'yer Mak'er
# 21                                        Dancing Days
# 22                                        Dancing Days
# 23                                             Darlene
# 24                                  Dazed And Confused
# 25                                  Dazed And Confused
# 26                                  Dazed and Confused
# 27                                  Dazed and Confused
# 28                                 Down by the Seaside
# 29                                    Fool in the Rain
# ..                                                 ...
# 93                              The Battle of Evermore
# 94                                          The Crunge
# 95        The Girl I Love She Got Long Black Wavy Hair
# 96                                      The Lemon Song
# 97                                           The Ocean
# 98                                           The Ocean
# 99                                       The Rain Song
# 100                                      The Rain Song
# 101                                          The Rover
# 102                          The Song Remains the Same
# 103                          The Song Remains the Same
# 104                                    The Wanton Song
# 105                                Trampled Under Foot
# 106                         Travelling Riverside Blues
# 107                         Travelling Riverside Blues
# 108                                      Walter's Walk
# 109                                 We're Gonna Groove
# 110                                Wearing and Tearing
# 111                   What Is And What Should Never Be
# 112                   What Is And What Should Never Be
# 113                   What Is and What Should Never Be
# 114                              When the Levee Breaks
# 115                                   Whole Lotta Love
# 116                                   Whole Lotta Love
# 117                                   Whole Lotta Love
# 118                                   Whole Lotta Love
# 119  Whole Lotta Love (Medley: Boogie Chillun'/Fixi...
# 120                                       You Shook Me
# 121                                       You Shook Me
# 116  You need coolin', baby, I'm not foolin' I'm go...
# 117  You need coolin', a-baby, I ain't foolin' I'm ...
# 118  You need coolin', baby, I'm not foolin' I'm go...
# 119  You need coolin', baby, I ain't foolin' I'm go...
# 120  You know you shook me, you shook me all night ...
# 121  I said you shook me You shook me all night lon...
# 122  Lyin', cheatin', hurtin', that's all you seem ...
#
# [123 rows x 5 columns]

# %%
lg=ldf["song"].groupby(ldf["albumy"]).count()
lg=lg.reset_index()
lg.rename(columns={'song': 'number of songs'}, inplace=True)
lg
# Out:
#                               albumy  number of songs
# 0                BBC Sessions (1997)               19
# 1                        Coda (1982)               10
# 2          Houses of the Holy (1973)                8
# 3        How The West Was Won (2003)               16
# 4     In Through the Out Door (1979)                7
# 5                Led Zeppelin (1969)                8
# 6             Led Zeppelin II (1969)                8
# 7            Led Zeppelin III (1970)               10
# 8             Led Zeppelin IV (1971)                8
# 9           Physical Graffiti (1975)               14
# 10                   Presence (1976)                7
# 11  The Song Remains the Same (1976)                8

# %%
albums=list(set(ldf.album.values))
year=[]
no_songs=[]
for a in albums:
    no_songs.append(len(list(set(ldf.loc[ldf['album']==a]['song'].values))))
    year.append(list(set(ldf.loc[ldf['album']==a]['year'].values))[0])
    y=' '.join(list(set(ldf.loc[ldf['album']==a]['year'].values)))
    c=[]
album = albums
lgy = pd.DataFrame(
    {'album': album,
     'year': year,
     'number of songs': no_songs
    })
lgy=lgy[["album",'year','number of songs']]
lgy.sort_values('year')
# Out:
#                         album  year  number of songs
# 0             Led Zeppelin II  1969                8
# 2                Led Zeppelin  1969                8
# 6            Led Zeppelin III  1970               10
# 10            Led Zeppelin IV  1971                8
# 11         Houses of the Holy  1973                8
# 5           Physical Graffiti  1975               14
# 3                    Presence  1976                7
# 8   The Song Remains the Same  1976                8
# 7     In Through the Out Door  1979                7
# 1                        Coda  1982               10
# 4                BBC Sessions  1997               19
# 9        How The West Was Won  2003               16

# %% [markdown]
# ### 1. The bipartite graph of songs and albums

# %%
sae=[]
for i in range(len(ldf)):
    s=ldf.iloc[i]['song']
    a=ldf.iloc[i]['album']
    y=ldf.iloc[i]['year']
    ly=ldf.iloc[i]['lyric']
    sae.append((s,a,y,ly))
saed=[]
for t in sae:
    year_l={'year_l':(t[2],t[3])}
    if t[0] not in ldf.album.unique():
        saed.append((t[0],t[1],year_l)) #,lyric))
    else:
        saed.append((t[0]+"_song",t[1],year_l))
saed=sorted(saed)
albums=list(set(ldf.album.values))
# songs=set(ldf.song.values)
t1=[]
t11=[]
t2=[]
for a in albums:
    for s in ldf.song.unique():
        if s==a:
            t11.append(s)
            ss=s+"_song"
            if ss not in t1:
                t1.append(ss)
for s in ldf.song.unique():
     if s not in t11:
        t2.append(s)
songs=t1+t2
for i in songs:
    if i in albums:
        print i
H=nx.MultiGraph()
H.add_edges_from(saed)
print "The graph H connecting the %i songs to the %i albums has: \n %i nodes and %i edges" %(len(songs),len(albums),len(H.nodes()),len(H.edges()))
print "Is H multigraph?", H.is_multigraph()
print "Is H bipartite?", nx.is_bipartite(H)
# Out:
# The graph H connecting the 89 songs to the 12 albums has:
#  101 nodes and 123 edges
# Is H multigraph? True
# Is H bipartite? True

# %%
# H.edges(data=True)

# %%
pos = nx.spring_layout(H, k=15.,iterations=1000)
r=0.3 #26
Ga=nx.Graph()
Ga.add_nodes_from(albums)
posalb=nx.circular_layout(Ga)
for a in albums:
    pos[a]=(r*posalb[a][0],r*posalb[a][1])

# %%
figsize=(15,15)

plt.figure(figsize=figsize);
nodes1 = nx.draw_networkx_nodes(H, pos, nodelist=list(albums),node_color="r",node_shape='s',alpha=0.5)#"#ffb3b3"
nodes2 = nx.draw_networkx_nodes(H, pos, nodelist=list(songs),node_size=0,node_color="g",node_shape='o',alpha=0.5)#"#b3ffb3"
nx.draw_networkx_edges(H, pos, edge_color="b", alpha=0.5)
plt.axis('off');
yoffset = {}
y_off = -0.04  # offset on the y axis
for k, v in pos.items():
    if k in albums:
        yoffset[k] = (v[0], v[1]+y_off)
    else:
        yoffset[k] = v
nx.draw_networkx_labels(H, yoffset,font_size=9);
sst="The bipartite graph of %s songs and albums" %band
plt.title(sst,fontsize=15);
plt.margins(x=0.1, y=0.1)

# %% [markdown]
# ### 2. The intersection graph of albums in the songs that they contain

# %%
aed=[]
for a1 in albums:
    for a2 in albums:
        if a2!=a1:
            t=[]
            for s in songs:
                if ((s,a1) in H.edges() and (s,a2) in H.edges()) or ((a1,s) in H.edges() and (a2,s) in H.edges()):
                    t.append(s)
            if len(t)>0:
                aed.append((a1, a2, len(t)))
waed=[]
for t in aed:
    weight={'weight':t[2]}
    waed.append((t[0],t[1],weight))
waed=sorted(waed)
HA=nx.Graph()
HA.add_edges_from(waed)
print "The graph HA connecting albums containing common songs has: \n %i nodes and %i edges" %(len(HA.nodes()),len(HA.edges()))
print "Is HA weighted?", nx.is_weighted(HA)
# Out:
# The graph HA connecting albums containing common songs has:
#  9 nodes and 18 edges
# Is HA weighted? True

# %%
weight=nx.get_edge_attributes(HA,'weight')
weight_list = [ e[2]['weight'] for e in HA.edges(data=True) ]
weight_list

cmap=plt.cm.jet #BrBG #ocean #coolwarm #plt.cm.tab20b
edge_color=weight_list
vmin = min(edge_color) 
vmax = max(edge_color) 
width_list=[0.6*w for w in weight_list] # [math.log(1+w) for w in weight_list]

plt.figure(figsize=(10,7));
pos = nx.spring_layout(HA, k=15, iterations=200) #graphviz_layout(HA)
node_border_color='k'
nodes = nx.draw_networkx_nodes(HA, pos=pos,node_shape='s', node_color='r', alpha=0.5) #'#A0CBE2')
nodes.set_edgecolor(node_border_color)
nx.draw_networkx_edges(HA, pos=pos,width=width_list,edge_color=weight_list,edge_cmap=cmap,vmin=vmin, vmax=vmax,alpha=0.5)
# nx.draw_networkx_edge_labels(HA,pos=pos,edge_labels=weight);
plt.axis('off');
yoffset = {}
y_off = -0.08  # offset on the y axis
for k, v in pos.items():
    yoffset[k] = (v[0], v[1]+y_off)
nx.draw_networkx_labels(HA, yoffset);
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm.set_array([])
cbar = plt.colorbar(sm,label="Common Songs") #, orientation='horizontal')
plt.tight_layout(-5)
sst="The intersection graph of %s albums" %band
plt.title(sst,fontsize=15);
plt.margins(x=0.2, y=0.1)

# %% [markdown]
# ### 3. The graph of co-occurring songs in the albums

# %%
aed=[]
for a1 in songs:
    for a2 in songs:
        if a2!=a1:
            t=[]
            for s in albums:
                if ((s,a1) in H.edges() and (s,a2) in H.edges()) or ((a1,s) in H.edges() and (a2,s) in H.edges()):
                    t.append(s)
            if len(t)>0:
                aed.append((a1, a2, len(t)))
waed=[]
for t in aed:
    weight={'weight':t[2]}
    waed.append((t[0],t[1],weight))
waed=sorted(waed)
HA=nx.Graph()
HA.add_edges_from(waed)
print "The graph HA connecting songs co-occurring in albums has: \n %i nodes and %i edges" %(len(HA.nodes()),len(HA.edges()))
print "Is HA weighted?", nx.is_weighted(HA)
# Out:
# The graph HA connecting songs co-occurring in albums has:
#  89 nodes and 589 edges
# Is HA weighted? True

# %%
weight=nx.get_edge_attributes(HA,'weight')
weight_list = [ e[2]['weight'] for e in HA.edges(data=True) ]
weight_list

cmap=plt.cm.jet #BrBG #ocean #coolwarm #plt.cm.tab20b
edge_color=weight_list
vmin = min(edge_color) 
vmax = max(edge_color) 
width_list=[math.log(1+w) for w in weight_list] # [0.6*w for w in weight_list]

plt.figure(figsize=(10,7));
pos=graphviz_layout(HA)
node_border_color='k'
nodes = nx.draw_networkx_nodes(HA, pos=pos,node_size=0,node_shape='s', node_color='r', alpha=0.5) #'#A0CBE2')
nodes.set_edgecolor(node_border_color)
nx.draw_networkx_edges(HA, pos=pos,width=width_list,edge_color=weight_list,edge_cmap=cmap,vmin=vmin, vmax=vmax,alpha=0.5)
plt.axis('off');
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm.set_array([])
cbar = plt.colorbar(sm,label="Shared Albums") #, orientation='horizontal')
plt.tight_layout(-5)
sst="The graph of co-occurrent %s songs in albums" %band
plt.title(sst,fontsize=15);

# %%
giant = max(nx.connected_component_subgraphs(HA), key=len)
plt.figure(figsize=(10,7));
HA=giant
weight=nx.get_edge_attributes(HA,'weight')
weight_list = [ e[2]['weight'] for e in HA.edges(data=True) ]
weight_list

cmap=plt.cm.jet #BrBG #ocean #coolwarm #plt.cm.tab20b
edge_color=weight_list
vmin = min(edge_color) 
vmax = max(edge_color) 
width_list=[math.log(1+w) for w in weight_list] # [0.6*w for w in weight_list]

pos=graphviz_layout(HA)
node_border_color='k'
nodes = nx.draw_networkx_nodes(HA, pos=pos,node_size=0,node_shape='s', node_color='r', alpha=0.5) #'#A0CBE2')
nodes.set_edgecolor(node_border_color)
nx.draw_networkx_edges(HA, pos=pos,width=width_list,edge_color=weight_list,edge_cmap=cmap,vmin=vmin, vmax=vmax,alpha=0.5)
plt.axis('off');
yoffset = {}
y_off = -0.08  # offset on the y axis
for k, v in pos.items():
    yoffset[k] = (v[0], v[1]+y_off)
nx.draw_networkx_labels(HA, yoffset,font_size=9,);
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm.set_array([])
cbar = plt.colorbar(sm,label="Shared Albums") #, orientation='horizontal')
plt.tight_layout(-5)
sst="The largest connected component of the \n graph of co-occurrent %s songs in albums" %band
plt.title(sst,fontsize=15);
plt.margins(x=0.1, y=0.05)
